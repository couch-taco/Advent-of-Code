# %% [markdown]
# <a href="https://colab.research.google.com/github/couch-taco/Advent-of-Code/blob/main/day_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install aocd
from aocd import get_data, submit
import pandas as pd
import numpy as np
import re
import math
puzzel_year = 2023
puzzel_day = 6
cookies = ''
raw = get_data(day = puzzel_day, year = puzzel_year, session= cookies)

# %%
from aocd import get_data, submit
import pandas as pd
import numpy as np
import re
import math

# %%
puzzel_year = 2023
puzzel_day = 6
cookies = ''
raw = get_data(day = puzzel_day, year = puzzel_year, session= cookies)

# %%
test_data = """Time:      7  15   30
Distance:  9  40  200"""

# %%
data = raw

# %%
# Splitting the string into lines
lines = data.split('\n')

# Extracting time and distance values
time_values = list(map(int, lines[0].split()[1:]))
distance_values = list(map(int, lines[1].split()[1:]))

# Creating a DataFrame
df = pd.DataFrame({'Time': time_values, 'Distance': distance_values})

# %%
df
# Out:
#    Time  Distance
# 0    56       499
# 1    97      2210
# 2    77      1097
# 3    93      1440

# %%
len(df)
# Out:
# 4

# %%
def equationroots( a, b, c):

    # calculating discriminant using formula
    dis = b * b - 4 * a * c
    sqrt_val = math.sqrt(abs(dis))

    # checking condition for discriminant
    if dis > 0:
        print("real and different roots")
        print((-b + sqrt_val)/(2 * a))
        root1 = (-b + sqrt_val)/(2 * a)
        print((-b - sqrt_val)/(2 * a))
        root2 = (-b - sqrt_val)/(2 * a)
    elif dis == 0:
        print("real and same roots")
        print(-b / (2 * a))
        root1 = -b / (2 * a)
    # when discriminant is less than 0
    else:
        print("Complex Roots")
        print(- b / (2 * a), + i, sqrt_val)
        print(- b / (2 * a), - i, sqrt_val)
    return root1, root2

# %%
rounded_roots = pd.DataFrame(columns= ('lower bound', 'upper bound'))
for x in np.arange(0, len(df), 1, dtype = int):
  roots = []
  roots = equationroots( -1, df.loc[x,'Time'], df.loc[x,'Distance']*-1)
  rounded_roots.loc[len(rounded_roots)] = [math.floor(roots[0]+1), math.ceil(roots[1])]
rounded_roots['diff']= rounded_roots['upper bound'] -rounded_roots['lower bound']
rounded_roots
# Out:
# real and different roots
# 11.118056983865866
# 44.88194301613413
# real and different roots
# 36.57313955812344
# 60.42686044187656
# real and different roots
# 18.87221357360948
# 58.12778642639052
# real and different roots
# 19.625290699246623
# 73.37470930075338
#    lower bound  upper bound  diff
# 0           12           45    33
# 1           37           61    24
# 2           19           59    40
# 3           20           74    54

# %%
rounded_roots.product()
# Out:
# lower bound      168720
# upper bound    11984670
# diff            1710720
# dtype: int64

# %% [markdown]
# #Part 2

# %%
time_values
# Out:
# 71530

# %%
# Splitting the string into lines
lines = data.split('\n')

# Extracting time and distance values
time_values = list(map(int, lines[0].split()[1:]))
time_values =int(''.join(map(str,time_values)))
distance_values = list(map(int, lines[1].split()[1:]))
distance_values =int(''.join(map(str,distance_values)))

rounded_roots = pd.DataFrame(columns= ('lower bound', 'upper bound'))
roots = []
roots = equationroots( -1, time_values, distance_values*-1)
rounded_roots.loc[len(rounded_roots)] = [math.floor(roots[0]+1), math.ceil(roots[1])]
rounded_roots['diff']= rounded_roots['upper bound'] -rounded_roots['lower bound']
rounded_roots
# Out:
# real and different roots
# 10814162.758970909
# 46163630.24102909
#    lower bound  upper bound      diff
# 0     10814163     46163631  35349468
